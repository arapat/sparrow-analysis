# %% [markdown]
# # Synthetic dataset - Deterministic, stumps

# %%
LOG_DIR = "../workbox/logs_synthetic/sd"
# %run sparrow-logs.ipynb
fig, ax = plt.subplots(3, 1, figsize=(10, 22))
plot_by_size(ax)
plot_xgb_by_size(ax)

exp_name = "on deterministic synthetic dataset (stumps)"
ax[0].set_title("Comparison of the potential between Sparrow and XGBoost\n" + exp_name);
ax[1].set_title("Comparison of the AURPC between Sparrow and XGBoost\n" + exp_name);
ax[2].set_title("Comparison of the AUROC between Sparrow and XGBoost\n" + exp_name);
for i in range(3):
    ax[i].set_xlabel("Number of trees")

# %% [markdown]
# # Synthetic dataset - Non-deterministic, stumps

# %%
LOG_DIR = "../workbox/logs_synthetic/sp"
# %run sparrow-logs.ipynb
fig, ax = plt.subplots(3, 1, figsize=(10, 22))
plot_by_size(ax)
plot_xgb_by_size(ax)

exp_name = "on non-determinisitc synthetic dataset (stumps)"
ax[0].set_title("Comparison of the potential between Sparrow and XGBoost\n" + exp_name);
ax[1].set_title("Comparison of the AURPC between Sparrow and XGBoost\n" + exp_name);
ax[2].set_title("Comparison of the AUROC between Sparrow and XGBoost\n" + exp_name);
for i in range(3):
    ax[i].set_xlabel("Number of trees")

# %% [markdown]
# # Synthetic dataset - Deterministic, trees

# %%
LOG_DIR = "../workbox/logs_synthetic/td2"
# %run sparrow-logs.ipynb
fig, ax = plt.subplots(3, 1, figsize=(10, 22))
plot_by_size(ax)
plot_xgb_by_size(ax)

exp_name = "on deterministic synthetic dataset (Trees)"
ax[0].set_title("Comparison of the potential between Sparrow and XGBoost\n" + exp_name);
ax[1].set_title("Comparison of the AURPC between Sparrow and XGBoost\n" + exp_name);
ax[2].set_title("Comparison of the AUROC between Sparrow and XGBoost\n" + exp_name);

for i in range(3):
    ax[i].set_xlabel("Number of trees")

# %% [markdown]
# # Synthetic dataset - Non-deterministic, trees

# %%
LOG_DIR = "../workbox/logs_synthetic/tp"
# %run sparrow-logs.ipynb
fig, ax = plt.subplots(3, 1, figsize=(10, 22))
plot_by_size(ax)
plot_xgb_by_size(ax)

exp_name = "on non-deterministic synthetic dataset (Trees)"
ax[0].set_title("Comparison of the potential between Sparrow and XGBoost\n" + exp_name);
ax[1].set_title("Comparison of the AURPC between Sparrow and XGBoost\n" + exp_name);
ax[2].set_title("Comparison of the AUROC between Sparrow and XGBoost\n" + exp_name);
for i in range(3):
    ax[i].set_xlabel("Number of trees")

# %% [markdown]
# # Small bathymetry dataset (labels are balanced)

# %%
LOG_DIR = "../workbox/logs_bal-bathymetry/"
# %run sparrow-logs.ipynb
fig, ax = plt.subplots(3, 1, figsize=(10, 18))
plot_by_size(ax)
plot_xgb_by_size(ax)

exp_name = "on deterministic synthetic dataset (stumps)"
ax[0].set_title("Comparison of the potential between Sparrow and XGBoost\n" + exp_name);
ax[1].set_title("Comparison of the AURPC between Sparrow and XGBoost\n" + exp_name);
ax[2].set_title("Comparison of the AUROC between Sparrow and XGBoost\n" + exp_name);

# %%
LOG_DIR = "../workbox/logs_bal-bathymetry/"
# %run sparrow-logs.ipynb
fig, ax = plt.subplots(3, 1, figsize=(10, 18))
plot_by_size(ax)
plot_xgb_by_size(ax)

exp_name = "on deterministic synthetic dataset (stumps)"
ax[0].set_title("Comparison of the potential between Sparrow and XGBoost\n" + exp_name);
ax[1].set_title("Comparison of the AURPC between Sparrow and XGBoost\n" + exp_name);
ax[2].set_title("Comparison of the AUROC between Sparrow and XGBoost\n" + exp_name);

# %%
LOG_DIR = "../workbox/logs_bal-bathymetry/"
# %run sparrow-logs.ipynb
fig, ax = plt.subplots(3, 1, figsize=(10, 18))
plot_by_size(ax)
plot_xgb_by_size(ax)

exp_name = "on deterministic synthetic dataset (stumps)"
ax[0].set_title("Comparison of the potential between Sparrow and XGBoost\n" + exp_name);
ax[1].set_title("Comparison of the AURPC between Sparrow and XGBoost\n" + exp_name);
ax[2].set_title("Comparison of the AUROC between Sparrow and XGBoost\n" + exp_name);

# %%
LOG_DIR = "../workbox/logs_bal-bathymetry/"
# %run sparrow-logs.ipynb
fig, ax = plt.subplots(3, 1, figsize=(10, 18))
plot_by_size(ax)
plot_xgb_by_size(ax)

exp_name = "on deterministic synthetic dataset (stumps)"
ax[0].set_title("Comparison of the potential between Sparrow and XGBoost\n" + exp_name);
ax[1].set_title("Comparison of the AURPC between Sparrow and XGBoost\n" + exp_name);
ax[2].set_title("Comparison of the AUROC between Sparrow and XGBoost\n" + exp_name);

# %%
LOG_DIR = "../workbox/logs_bal-bathymetry/sp128/"
# %run sparrow-logs.ipynb
fig, ax = plt.subplots(3, 1, figsize=(10, 18))
plot_by_size(ax)
plot_xgb_by_size(ax)

exp_name = "on deterministic synthetic dataset (stumps)"
ax[0].set_title("Comparison of the potential between Sparrow and XGBoost\n" + exp_name);
ax[1].set_title("Comparison of the AURPC between Sparrow and XGBoost\n" + exp_name);
ax[2].set_title("Comparison of the AUROC between Sparrow and XGBoost\n" + exp_name);
