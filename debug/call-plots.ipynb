# %%
ls ../workbox/logs_synthetic/sd
# Out:
# models/           stratified.bin    training.log      xgb-r16-t8.model
# models_table.txt  testing.log       xgb-r16-t8.bin    xgboost.log

# %%
LOG_DIR = "../workbox/logs_synthetic/sd"
# %run sparrow-logs.ipynb
fig, ax = plt.subplots(3, 1, figsize=(10, 18))
plot_by_size(ax)
plot_xgb_by_size(ax)

# %%
LOG_DIR = "../workbox/logs_synthetic/sp"
# %run sparrow-logs.ipynb
fig, ax = plt.subplots(3, 1, figsize=(10, 18))
plot_by_size(ax)
plot_xgb_by_size(ax)

# %%
LOG_DIR = "../workbox/logs_synthetic/td"
# %run sparrow-logs.ipynb
fig, ax = plt.subplots(3, 1, figsize=(10, 18))
plot_by_size(ax)
plot_xgb_by_size(ax)

# %%
LOG_DIR = "../workbox/logs_synthetic/tp"
# %run sparrow-logs.ipynb
fig, ax = plt.subplots(3, 1, figsize=(10, 18))
plot_by_size(ax)
plot_xgb_by_size(ax)

# %%
LOG_DIR = "../workbox/logs_bal-bathymetry/"
# %run sparrow-logs.ipynb
fig, ax = plt.subplots(3, 1, figsize=(10, 18))
plot_by_size(ax)
plot_xgb_by_size(ax)
